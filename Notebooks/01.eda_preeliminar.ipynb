# %%
#Tratamiento de datos
import pandas as pd 
pd.set_option('display.max_columns',None)

#Exploracion de archivos
import sys
sys.path.append("../")

#Funciones personalizadas
from src import eda as se

# %%
df = pd.read_csv("../Data/data_raw.csv")

# %%
se.eda_preeliminar(df)
# Out:
#       User Id Group  Visit Date  Conversion Product Category Product Id  \
# 19         20     A  2022-03-09           0           BEAUTY      P1005
# 1416     1417     A  2022-03-24           0            BOOKS      P1800
# 638       639     A  2022-02-01           0      ELECTRONICS      P1704
# 1444     1445     B  2022-03-09           1             HOME      P1671
# 1195     1196     B  2022-03-31           0           SPORTS      P1695
#
#      Product Name  Quantity   Price Discount Total Value Payment Method  \
# 19        Perfume         0  123,68     0,09         0,0            NaN
# 1416      Mystery         0   26,12     0,15         0,0            NaN
# 638    Smartphone         0  516,59     0,26         0,0            NaN
# 1444        Table         3  375,31     0,26      833,19         PayPal
# 1195     Football         0  225,27     0,03         0,0            NaN
#
#      Shipping Method   Region  Customer Age Customer Gender   Device  \
# ...
